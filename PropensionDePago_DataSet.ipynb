# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolinaG2024/Allura-Store_Challenge/blob/main/PropensionDePago_DataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Preparación del ambiente
#
# El modelo será estructurado con Python aprovechando sus diferentes librerias.
#
# Para la importación de datos, teniendo en cuenta el volumen historico de información requerida se utilizará Kaggle como herramienta.

# %% [markdown]
# ## 1. Importación de Librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score

# Configuración de visualización
# %matplotlib inline
sns.set_theme(style="whitegrid")

# Simulación de carga de datos (Sustituir por conexión a BigQuery o CSV)
# df = pd.read_csv('gestion_cobranza_utilities.csv')
print("Entorno preparado para el análisis de propensión.")

# %% [markdown]
# # Eleccion del Dataset
#
# El modelo utiliza CUATRO fuentes de información primaria:
#
# *   Ordenes: Tabla de datos estructurados que contiene información del potencial de usuarios del servicio que es generado desde el sistema del cliente. Esta es la entrada para identificar los usuarios a los que se debe realizar el analisis, se genera a diario.
#
# *  Balanza: Tabla de datos estructurados que contiene información de la deuda de cada usuario del servicio y variables para su caracterización.  Se utilizara información historica de 12 meses tomando el archivo de cierre de cada mes.
#
# *   Consolidado: Tabla de datos estructurados que contiene la información de las intervenciones que se han realizado a los usuarios del servicio desde la operativa del contratista. Se utilizara información histórica de 12 meses tomando el archivo de cierre de cada mes.
#
# *   Criterios de asignación:  Contiene las reglas del negocio para determinar la asignación de las cuadrillas y alcance según tipo de operación.

# %% [markdown]
# ## 1. Importación de Datos

# %% [markdown]
# ## 2. Generación del Dataframe

# %% [markdown]
# ## 3. Eliminación de Variables

# %% [markdown]
# ## 4. Guardado del Dataframe
